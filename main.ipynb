# %%
import pandas as pd

# %%
path="C:/Users/addisu/Documents/GitHub/news_correlation_10ac_week0/data.csv/rating.csv"
df=pd.read_csv(path)
df.head(5)
# Out:
#    article_id source_id     source_name  \
# 0       81664       NaN          Forbes
# 1       81667       NaN             CNA
# 2       81694      time            Time
# 3       81695       NaN        Phys.Org
# 4       81703       NaN  Digital Trends
#
#                                               author  \
# 0  Elizabeth Brownfield, Contributor, \n Elizabet...
# 1                                                NaN
# 2                              Christina Larson / AP
# 3                                       Sara Schmidt
# 4                                       Jason Struss
#
#                                                title  \
# 0  superstar chef yannick alléno brings refined f...
# 1  nice claim top spot in ligue 1 with late win a...
# 2  amphibians are the world’s most vulnerable spe...
# 3              image: rusty red waters in madagascar
# 4  everything leaving max (formerly hbo max) in n...
#
#                                          description  \
# ...

# %%
path="C:/Users/addisu/Documents/GitHub/news_correlation_10ac_week0/traffic_data/traffic.csv"
df1=pd.read_csv(path)
df1.head(5)
# Out:
#    GlobalRank  TldRank         Domain  TLD  RefSubNets   RefIPs  \
# 0           1        1     google.com  com      471274  2151358
# 1           2        2   facebook.com  com      465424  2250631
# 2           3        3    youtube.com  com      420579  1852995
# 3           4        4    twitter.com  com      404985  1757127
# 4           5        5  instagram.com  com      364746  1598085
#
#       IDN_Domain IDN_TLD  PrevGlobalRank  PrevTldRank  PrevRefSubNets  \
# 0     google.com     com               1            1          471248
# 1   facebook.com     com               2            2          465297
# 2    youtube.com     com               3            3          420483
# 3    twitter.com     com               4            4          404998
# 4  instagram.com     com               5            5          364618
#
#    PrevRefIPs
# 0     2147402
# 1     2247135
# 2     1848940
# 3     1753939
# 4     1594892

# %%
#  1. Websites that have the largest count of news articles

largest_websites = df['source_name'].value_counts().nlargest(10)
print(largest_websites)
# Out:
# source_name
# ETF Daily News        16746
# The Times of India     7504
# GlobeNewswire          5423
# Globalsecurity.org     3119
# Forbes                 2784
# BBC News               2113
# ABC News               2058
# Business Insider       2034
# The Punch              1800
# Al Jazeera English     1664
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
# Plot the count of news articles for each website
plt.figure(figsize=(10, 6))
largest_websites.plot(kind='bar', color='skyblue')
plt.title('Top 10 Websites by Article Count')
plt.xlabel('Website')
plt.ylabel('Article Count')
plt.xticks(rotation=45)
plt.show()

# %%
# 2.Websites with the highest numbers of visitors traffic 
highest_traffic_websites = df1.nlargest(10, 'GlobalRank')
print(highest_traffic_websites)
# Out:
#         GlobalRank  TldRank                  Domain  TLD  RefSubNets  RefIPs  \
# 999999     1000000   485328  toyotamusicfactory.com  com         222     280
# 999998      999999   485327          soderhomes.com  com         222     280
# 999997      999998   485326           pinkwater.com  com         222     280
# 999996      999997   485325             mt-lock.com  com         222     280
# 999995      999996   485324              kireie.com  com         222     280
# 999994      999995   485323         keith-baker.com  com         222     280
# 999993      999994   485322          irishcycle.com  com         222     280
# 999992      999993   485321                hmag.com  com         222     280
# 999991      999992   485320    exploring-africa.com  com         222     280
# 999990      999991   485319            eiretrip.com  com         222     280
#
#                     IDN_Domain IDN_TLD  PrevGlobalRank  PrevTldRank  \
# ...

# %%
# Plot the global rank of the top 10 websites
plt.figure(figsize=(10, 6))
plt.barh(highest_traffic_websites['Domain'], highest_traffic_websites['GlobalRank'], color='lightgreen')
plt.title('Top 10 Websites by Global Rank (Visitor Traffic)')
plt.xlabel('Global Rank')
plt.ylabel('Website')
plt.gca().invert_yaxis()  # Reverse the y-axis to show the highest rank at the top
plt.show()

# %%
# Plot the global rank of the top 10 websites using a log scale for the y-axis
plt.figure(figsize=(10, 6))
plt.barh(highest_traffic_websites['Domain'], highest_traffic_websites['GlobalRank'], color='lightgreen')
plt.title('Top 10 Websites by Global Rank (Visitor Traffic)')
plt.xlabel('Global Rank')
plt.ylabel('Website')
plt.xscale('log')  # Use a log scale for the x-axis
plt.gca().invert_yaxis()  # Reverse the y-axis to show the highest rank at the top
plt.show()

# %%
path="C:/Users/addisu/Documents/GitHub/news_correlation_10ac_week0/domains_location.csv"
df2=pd.read_csv(path)
df2.head(5)
# Out:
#   SourceCommonName location    Country
# 0       00221.info       SG    Senegal
# 1        01net.com       FR     France
# 2         01net.it       IT      Italy
# 3      0223.com.ar       AR  Argentina
# 4     022china.com       CH      China

# %%
# 3.Countries with the highest number of news media organisations (represented by domains in the data)
highest_news_media_organisations = df2['Country'].value_counts().nlargest(10)
print(highest_news_media_organisations)
# Out:
# Country
# United States     14111
# United Kingdom     1950
# Italy              1810
# France             1041
# Russia             1024
# Canada              887
# Germany             884
# China               780
# Turkey              725
# India               686
# Name: count, dtype: int64

# %%
# Plot the count of news media organizations for each country
plt.figure(figsize=(10, 6))
highest_news_media_organisations.plot(kind='bar', color='lightcoral')
plt.title('Top 10 Countries by Number of News Media Organizations')
plt.xlabel('Country')
plt.ylabel('Number of News Media Organizations')
plt.xticks(rotation=45)
plt.show()

# %%
# 5.Websites that reported (the news content) about Africa, US, China, EU, Russia, Ukraine, Middle East? Note that you will need to group countries together to form the African, EU, and Middle East continents/regions.



# # Create a dictionary to map countries to their corresponding regions


#  [ ] first df['category'].unique( )   / to know the listsin the category and then to insert in their corresponding region like 'south sudan' to africa

country_to_region = {
    'Africa': ['Madagascar','Mali'],  # Add more African countries as needed
    'US': ['United States', 'USA'],  # Add more US-related keywords as needed
    'China': ['China'],  # Add more Chinese-related keywords as needed
    'EU': ['European Union', 'Germany', 'France', 'UK'],  # Add more EU-related keywords as needed
    'Russia': ['Russia'],  # Add more Russian-related keywords as needed
    'Ukraine': ['Ukraine'],  # Add more Ukrainian-related keywords as needed
    'Middle East': ['Middle East', 'Saudi Arabia', 'Iran']  # Add more Middle Eastern countries as needed
}

# Create a new column for each region indicating if it's mentioned in the content
for region, countries in country_to_region.items():
    df[region] = df['content'].str.contains('|'.join(countries), case=False)

# Count the occurrences of each region across all articles
region_counts = df[list(country_to_region.keys())].sum()

print("Number of articles mentioning each region:")
print(region_counts)
# Out:
# Number of articles mentioning each region:
# Africa          155
# US             1799
# China          1000
# EU             2637
# Russia         1312
# Ukraine         868
# Middle East    1035
# dtype: int64

# %%
# Calculate the raw message lengths for each site
df['message_length'] = df['content'].str.len()

# Calculate the number of words in the title for each site
df['title_word_count'] = df['title'].str.split().apply(len)

# Visualize the distribution of raw message lengths across sites
plt.figure(figsize=(10, 6))
df.boxplot(column='message_length', by='source_name', vert=False)
plt.title('Distribution of Raw Message Lengths Across Sites')
plt.xlabel('Message Length')
plt.ylabel('Site')
plt.show()

# Visualize the distribution of title word counts across sites
plt.figure(figsize=(10, 6))
df.boxplot(column='title_word_count', by='source_name', vert=False)
plt.title('Distribution of Title Word Counts Across Sites')
plt.xlabel('Title Word Count')
plt.ylabel('Site')
plt.show()

# %%
print(df.head())
# print(df1.head())
# print(df2.head())
# Out:
#    GlobalRank  TldRank         Domain  TLD  RefSubNets   RefIPs  \
# 0           1        1     google.com  com      471274  2151358
# 1           2        2   facebook.com  com      465424  2250631
# 2           3        3    youtube.com  com      420579  1852995
# 3           4        4    twitter.com  com      404985  1757127
# 4           5        5  instagram.com  com      364746  1598085
#
#       IDN_Domain IDN_TLD  PrevGlobalRank  PrevTldRank  PrevRefSubNets  \
# 0     google.com     com               1            1          471248
# 1   facebook.com     com               2            2          465297
# 2    youtube.com     com               3            3          420483
# 3    twitter.com     com               4            4          404998
# 4  instagram.com     com               5            5          364618
#
#    PrevRefIPs
# 0     2147402
# 1     2247135
# 2     1848940
# 3     1753939
# 4     1594892

# %%
# 5.Websites that reported (the news content) about Africa, US, China, EU, Russia, Ukraine, Middle East? Note that you will need to group countries together to form the African, EU, and Middle East continents/regions.

# # Create a dictionary to map countries to their corresponding regions

#  [ ] first df['category'].unique( )   / to know the listsin the category and then to insert in their corresponding region like 'south sudan' to africa

country_to_region = {
    'Africa': ['Madagascar','Mali'],  # Add more African countries as needed
    'US': ['United States', 'USA'],  # Add more US-related keywords as needed
    'China': ['China'],  # Add more Chinese-related keywords as needed
    'EU': ['European Union', 'Germany', 'France', 'UK'],  # Add more EU-related keywords as needed
    'Russia': ['Russia'],  # Add more Russian-related keywords as needed
    'Ukraine': ['Ukraine'],  # Add more Ukrainian-related keywords as needed
    'Middle East': ['Middle East', 'Saudi Arabia', 'Iran']  # Add more Middle Eastern countries as needed
}

# # Create a new column for each region indicating if it's mentioned in the content
for region, countries in country_to_region.items():
    df[region] = df['content'].str.contains('|'.join(countries), case=False)

# # Count the occurrences of each region across all articles
region_counts = df[list(country_to_region.keys())].sum()

print("Number of articles mentioning each region:")
print(region_counts)
# Out:
# Number of articles mentioning each region:
# Africa          155
# US             1799
# China          1000
# EU             2637
# Russia         1312
# Ukraine         868
# Middle East    1035
# dtype: int64

# %%
# Websites with the highest count of positive, neutral, and negative sentiment

# Assuming you have the data in a DataFrame called cleaned_df with the specified columns

# Group the data by website domain and sentiment, then apply descriptive statistics
website_sentiment_stats = df.groupby(['source_name', 'title_sentiment']).size().unstack(fill_value=0)

# Apply descriptive statistics to the grouped data for each website
descriptive_stats_by_media = website_sentiment_stats.groupby('source_name').agg({'Positive': ['mean', 'median', 'var'], 'Neutral': ['mean', 'median', 'var'], 'Negative': ['mean', 'median', 'var']})

# Display the descriptive statistics for each website
print(descriptive_stats_by_media)
# Out:
# title_sentiment              Positive              Neutral               \
#                                  mean  median var     mean   median var
# source_name
# ABC News                        139.0   139.0 NaN   1193.0   1193.0 NaN
# Al Jazeera English               31.0    31.0 NaN    927.0    927.0 NaN
# AllAfrica - Top Africa News       0.0     0.0 NaN     12.0     12.0 NaN
# Android Central                 272.0   272.0 NaN    212.0    212.0 NaN
# BBC News                         74.0    74.0 NaN   1185.0   1185.0 NaN
# Boing Boing                     170.0   170.0 NaN    293.0    293.0 NaN
# Business Insider                237.0   237.0 NaN    907.0    907.0 NaN
# CNA                              86.0    86.0 NaN    462.0    462.0 NaN
# CNN                              23.0    23.0 NaN    142.0    142.0 NaN
# Deadline                         54.0    54.0 NaN    794.0    794.0 NaN
# Digital Trends                  406.0   406.0 NaN    335.0    335.0 NaN
# ...
